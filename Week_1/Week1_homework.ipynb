# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
# from sklearn.linear_model import Lasso
# from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
df = pd.read_parquet('./data/yellow_tripdata_2022-01.parquet')

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count
# 0               1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0  \
# 1               1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2               2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3               2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4               2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# ...           ...                  ...                   ...              ...
# 2463926         2  2022-01-31 23:36:53   2022-01-31 23:42:51              NaN
# 2463927         2  2022-01-31 23:44:22   2022-01-31 23:55:01              NaN
# 2463928         2  2022-01-31 23:39:00   2022-01-31 23:50:00              NaN
# 2463929         2  2022-01-31 23:36:42   2022-01-31 23:48:45              NaN
# 2463930         2  2022-01-31 23:46:00   2022-02-01 00:13:00              NaN
#
# ...

# %%
df.dtypes
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# airport_fee                     float64
# dtype: object

# %%
# df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
# df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

# df = df[(df.duration >= 1) & (df.duration <= 60)]

# %%
df.tpep_dropoff_datetime - df.tpep_pickup_datetime
# Out:
# 0         0 days 00:17:49
# 1         0 days 00:08:24
# 2         0 days 00:08:58
# 3         0 days 00:10:02
# 4         0 days 00:37:32
#                 ...
# 2463926   0 days 00:05:58
# 2463927   0 days 00:10:39
# 2463928   0 days 00:11:00
# 2463929   0 days 00:12:03
# 2463930   0 days 00:27:00
# Length: 2463931, dtype: timedelta64[ns]

# %%
df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)
df.duration # duration is in minutes
# Out:
# 0          17.816667
# 1           8.400000
# 2           8.966667
# 3          10.033333
# 4          37.533333
#              ...
# 2463926     5.966667
# 2463927    10.650000
# 2463928    11.000000
# 2463929    12.050000
# 2463930    27.000000
# Name: duration, Length: 2463931, dtype: float64

# %%
# sns.displot(df.duration)

# %%
# sns.histplot(
#     df.duration, kde=True,
#     stat="density", kde_kws=dict(cut=3),
#     alpha=.4, edgecolor=(1, 1, 1, .4),
# )

# %%
df.duration.describe()
# df.duration.describe(percentiles=[0.95, 0.98, 0.99])
# Out:
# count    2.463931e+06
# mean     1.421220e+01
# std      4.644531e+01
# min     -3.442400e+03
# 25%      6.316667e+00
# 50%      1.018333e+01
# 75%      1.616667e+01
# max      8.513183e+03
# Name: duration, dtype: float64

# %%
df_old = df
df = df[(df.duration >= 1) & (df.duration <= 60)]

df.duration.describe(percentiles=[0.95, 0.98, 0.99])
# Out:
# count    2.421440e+06
# mean     1.267128e+01
# std      8.999282e+00
# min      1.000000e+00
# 50%      1.023333e+01
# 95%      3.105000e+01
# 98%      3.971667e+01
# 99%      4.568333e+01
# max      6.000000e+01
# Name: duration, dtype: float64

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count
# 0               1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0  \
# 1               1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2               2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3               2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4               2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# ...           ...                  ...                   ...              ...
# 2463926         2  2022-01-31 23:36:53   2022-01-31 23:42:51              NaN
# 2463927         2  2022-01-31 23:44:22   2022-01-31 23:55:01              NaN
# 2463928         2  2022-01-31 23:39:00   2022-01-31 23:50:00              NaN
# 2463929         2  2022-01-31 23:36:42   2022-01-31 23:48:45              NaN
# 2463930         2  2022-01-31 23:46:00   2022-02-01 00:13:00              NaN
#
# ...

# %%
row_diff = len(df.axes[0])/len(df_old.axes[0])
print("Fraction of the records left after we dropped the outliers is {0:.0%}".format(row_diff))
# Out:
# Fraction of the records left after we dropped the outliers is 98%

# %%
categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

df[categorical] = df[categorical].astype(str)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11220\833933397.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[categorical] = df[categorical].astype(str)

# %%
# print(df['PULocationID'].nunique())
# print(df['DOLocationID'].nunique())
dim = df['PULocationID'].nunique() + df['DOLocationID'].nunique()
print("Dimensionality of this matrix (number of columns) = "+str(dim))
# Out:
# Dimensionality of this matrix (number of columns) = 515

# %%
train_dicts = df[categorical + numerical].to_dict(orient='records')

# feature matrix
dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

# target variable
target = 'duration'
y_train = df[target].values

lr = LinearRegression()
lr.fit(X_train, y_train)

# prediction
y_pred = lr.predict(X_train)

# root mean squared error (RMSE)
mean_squared_error(y_train, y_pred, squared=False)
# Out:
# 7.001496179360711

# %%
len(dv.feature_names_)
# Out:
# 516

# %%
X_train.shape
# Out:
# (2421440, 516)

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
# training data set - Yellow Jan data
df_train = read_dataframe('./data/yellow_tripdata_2022-01.parquet')
# validation data set - Yellow Feb data
df_val = read_dataframe('./data/yellow_tripdata_2022-02.parquet')

len(df_train), len(df_val)
# Out:
# (2421440, 2918187)

# %%
categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

# RMSE of validation
mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 7.795498400456978

# %%
# lr = Lasso(0.01)
# lr.fit(X_train, y_train)

# y_pred = lr.predict(X_val)

# mean_squared_error(y_val, y_pred, squared=False)
